# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# http://jonathansoma.com/lede/algorithms-2017/classes/fuzziness-matplotlib/how-pandas-uses-matplotlib-plus-figures-axes-and-subplots/

# %%
#orb_homomorphic = pd.read_csv('volog_orb_homomorphic.csv', skipinitialspace=True, usecols=['nmatches'])
orb_homomorphic = pd.read_csv('volog_orb_homomorphic.csv', 
                              converters = {'ex_time': lambda x: (float(x)*1000)})
orb_homomorphic
# Out:
#       Unnamed: 0 feature  nmatches  ngoodmatches     ex_time
# 0              0     orb     985.0          50.0  437.623978
# 1              0     orb     985.0          50.0  174.238920
# 2              0     orb     988.0          50.0  138.035059
# 3              0     orb     989.0          50.0  165.397882
# 4              0     orb     989.0          39.0  146.272898
# 5              0     orb     945.0          10.0  213.401079
# 6              0     orb    2000.0           9.0  289.176941
# 7              0     orb     939.0          10.0  296.336174
# 8              0     orb    2000.0          10.0  270.870924
# 9              0     orb     951.0          10.0  284.782887
# 10             0     orb    2000.0          10.0  251.178980
# 11             0     orb     950.0           9.0  343.116999
# 12             0     orb    2000.0           8.0  277.101040
# 13             0     orb     870.0           9.0  274.765968
# ...

# %%
orb_homom_time = orb_homomorphic.boxplot(column=['ex_time'])
orb_homom_time

# %%
orb_homom_good = orb_homomorphic.boxplot(column=['ngoodmatches'])
orb_homom_good

# %%
orb_homom_matches = orb_homomorphic.boxplot(column=['nmatches'])
orb_homom_matches

# %%
orb = pd.read_csv('volog_orb.csv', 
                converters = {'ex_time': lambda x: (float(x)*1000)})
orb
# Out:
#       Unnamed: 0 feature  nmatches  ngoodmatches     ex_time
# 0              0     orb    2000.0          50.0  554.494143
# 1              0     orb    2000.0          48.0  345.182896
# 2              0     orb    2000.0          14.0  385.129929
# 3              0     orb    2000.0          24.0  386.390209
# 4              0     orb    2000.0          44.0  330.739021
# 5              0     orb    2000.0          50.0  318.454027
# 6              0     orb    2000.0          46.0  316.231012
# 7              0     orb    2000.0          35.0  345.846891
# 8              0     orb    2000.0          22.0  359.233141
# 9              0     orb    1996.0          50.0  348.699093
# 10             0     orb    1998.0          16.0  342.814922
# 11             0     orb    2000.0          44.0  328.660965
# 12             0     orb    2000.0          50.0  399.133921
# 13             0     orb    2000.0          17.0  341.694832
# ...

# %%
orb_time = orb.boxplot(column=['ex_time'])
orb_time

# %%
orb_good = orb.boxplot(column=['ngoodmatches'])
orb_good
